# %% [markdown]
# # Probability Density Function
#
# $
# \text{Normal distribution} \\
# $
# $$
# X \sim N(\mu,\sigma^2) \\
# $$
# $
# \text{Probability density function} \\
# $
# $$
# f(x)=\frac{1}{\sigma \sqrt{2 \pi}}e^{-\frac{(x- \mu)^2}{2 \sigma^2}}\text{, where $x\in \mathbb{R}$}
# $$

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt


x= np.arange(-4,4,0.001)
plt.plot(x, norm.pdf(x))
plt.title("N(0,1)")
plt.xlabel('x')
plt.ylabel('P(x)')
plt.grid(True)
plt.show()

# %%
norm.pdf(x=1.0, loc=0, scale=1)
# Out:
# 0.24197072451914337

# %% [markdown]
# `scipy.norm.pdf` has keywards, `loc` and `scale`. The location (loc) keyword specifies the mean and the scale (scale) keyword specifies the standard deviation.

# %% [markdown]
# Probability distribution functions where mean is 0 and different standard deviations.

# %%
x = np.linspace(-10,10,100)
stdvs = [1.0, 2.0, 3.0, 4.0]

for s in stdvs:
    plt.plot(x, norm.pdf(x,scale=s), label='stdv=%.1f' % s)
    
plt.xlabel('x')
plt.ylabel('p(x)')
plt.title('Normal Distribution')
plt.legend(loc='best', frameon=True)
plt.grid(True)

# %%
x = np.linspace(-10,10,100)
mus = [0.0, 1.0, 2.0, 5.0]

for mu in mus:
    plt.plot(x, norm.pdf(x,loc=mu), label='mean=%.1f' % mu)
    
plt.xlabel('x')
plt.ylabel('p(x)')
plt.title('Normal Distribution')
plt.legend(loc='best', frameon=False)
plt.grid(True)

# %%
xs = norm.rvs(scale=2,size=1000)
x = np.linspace(-10,10,100)
p = norm.pdf(x,scale=2)
v = np.var(xs)
m = np.mean(xs)
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(xs, bins=10, alpha=0.5, density=True)
ax.plot(x,p, 'r-', lw=2)
ax.set_xlabel('x')
ax.set_ylabel('p(x)')
ax.set_title('hist mean=%.2f, var=%.2f' % (m,v))
ax.grid(True)

# %% [markdown]
# # Cumulative normal distribution function
#
# $$
# F(x)=\int \limits _{-\infty} ^{x}f(t)dt \text{, where }x\in \mathbb{R}
# $$

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

x= np.arange(-4,4,0.001)
plt.plot(x, norm.pdf(x))
plt.title("Cumulative normal distribution")
plt.xlabel('x')
plt.ylabel('P(x)')
plt.grid(True)

px=np.arange(-4,0,0.01)
plt.ylim(0,0.5)
plt.fill_between(px,norm.pdf(px),alpha=0.5)
px1=np.arange(2,4,0.01)
plt.fill_between(px1,norm.pdf(px1),alpha=0.5, color='green')
plt.show()

# %% [markdown]
# # References
#
# - https://qiita.com/supersaiakujin/items/71540d1ecd60ced65add
# - http://kaisk.hatenadiary.com/entry/2015/02/17/192955
