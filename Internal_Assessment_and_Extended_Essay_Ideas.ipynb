# %% [markdown]
# # IA & EE Ideas Resources: Focused on Statistics and Data Science.
#
# ## IB Resources
# - [Guide Extended Essay](https://drive.google.com/file/d/1aqx2eP4GUujqCAZH4g781UXr9QvNnYVE/view?usp=sharing)
# - [Internal Assessment](https://drive.google.com/file/d/1PKDVnhmtlDB-VZ8RfdJmqf1Y6U7qWupC/view?usp=sharing)
#
# ## Data
# - [Data Sources](https://medium.com/@shinichiokada/list-of-data-sources-de586e4fdd7?source=friends_link&sk=b57ca4c7f42d27dd81141a2d300a1813)
#
# ## Statistics
# ### SL/HL
# - Mean, mode, median
# - Outliers, Quartile, IQR
# - Standard deviation, Variance
# - Linear correlation of bivariate data, Pearson's product-moment correlation
# - Spearman's rank correlation
# - Chi-square test for independence
# - Chi-square test for goodness of fit
# - T-test
# - p-value
# - Probability, the expected value
# - Binomial distribution
# - Normal distribution
# - Different ways to find [Outliers](https://statisticsbyjim.com/basics/outliers/) and practical example, [Link](https://www.itl.nist.gov/div898/handbook/eda/section3/eda35h.htm),[Link](https://towardsdatascience.com/5-ways-to-detect-outliers-that-every-data-scientist-should-know-python-code-70a54335a623)
# - Variance
#
# ### HL
# - Least squares regression, squared residuals
# - Linear transformation of a single random variable E(aX+b)=aE(X)+b, etc
# - Unbiased estimate
# - Central limit theorem
# - Confidence intervals for the mean of a normal population
# - Non-linear regression
# - Poisson distribution
# - comparing different way to find [quartile](http://mathworld.wolfram.com/Quartile.html)
# - the standard error of mean
# - [Central Limit theorem](https://math.stackexchange.com/questions/504288/what-situation-calls-for-dividing-the-standard-deviation-by-sqrt-n) or [Square Root n Law](https://www.causeweb.org/smiles/readings/square-root-law-for-standard-error) and its practical usage.
# - Bayes' Themorem
# - Uniform continuous distribution
#
# ## Resources
#
# - [Mr. Okada Github](https://github.com/shinokada/python-for-ib-diploma-mathematics)
# - [Beginner's Guide to Jupyter Notebook (From the setup to the descriptive statistics)](https://towardsdatascience.com/beginners-guide-to-jupyter-notebook-8bb85b85085)
# - [A Measure of Linear Relationship (Pearson’s product-moment correlation with Jupyter Notebook)](https://towardsdatascience.com/beginners-guide-to-jupyter-notebook-8bb85b85085)
# - [Discover the strength of monotonic relation (Finding Spearman’s rank correlation coefficient using Jupyter Notebook)](https://towardsdatascience.com/discover-the-strength-of-monotonic-relation-850d11f72046?source=friends_link&sk=e399b8b76149a133f1195baf520b8987)
# - [Gentle Introduction to Chi-square test for independence](https://towardsdatascience.com/gentle-introduction-to-chi-square-test-for-independence-7182a7414a95)
#
#
#
# # Advanced
# ## Statistics
# - Confidence interval, prediction interval and tolerance intervals
#
# ## Algorithms
# Investigate one of the algorithms and it's practical usage.
#
# - Interpolation method ([Quartile](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.quantile.html), etc)
# - [Multiple linear regression](https://towardsdatascience.com/a-beginners-guide-to-linear-regression-in-python-with-scikit-learn-83a8f7ae2b4f), [regression coefficients](https://stattrek.com/multiple-regression/regression-coefficients.aspx)
# - [Support Vector Machines](https://www.wikiwand.com/en/Support_Vector_Machines)
# - [Logistic regression](https://www.wikiwand.com/en/Logistic_regression), [Linear regression vs logistic regression](https://www.datacamp.com/community/tutorials/understanding-logistic-regression-python), [reference](https://medium.com/@anishsingh20/logistic-regression-in-python-423c8d32838b)
# - [Naive Bayes](https://www.wikiwand.com/en/Naive_Bayes_classifier)
# - Linear discriminant analysis
# - [Decision trees](https://www.wikiwand.com/en/Decision_tree_learning)
# - [k-nearest neighbor algorithm](https://www.wikiwand.com/en/K-nearest_neighbor_algorithm)
# - [Neural Networks (Multilayer perceptron)](https://www.wikiwand.com/en/Artificial_neural_network)
# - [Similarity learning](https://www.wikiwand.com/en/Similarity_learning)
# - Ordinary Least Squares in a linear model
# - Kernel Density Estimation (non-parametric smoothing technique)
# - [Variance Inflation Factor](https://towardsdatascience.com/super-simple-machine-learning-by-me-multiple-linear-regression-part-1-447800e8b624)
# - [Covariance and correlation](https://corporatefinanceinstitute.com/resources/knowledge/finance/covariance/) Find some data to use your understanding.
# - Receiver Operating Characteristic
# - [Log loss binary classification (Loss function)](https://towardsdatascience.com/understanding-binary-cross-entropy-log-loss-a-visual-explanation-a3ac6025181a)
# - Mean absolute error, mean squared error and root mean squared error.
# - Step function
# - Sigmoid function
# - Logit function
# - ReLU (Rectified Linear Unit) function
# - Cost function
# - Gradient Descent
#
# ## Distributions
# - Univariate distribution and the kernel density function
#
# ## Test
# - [F-Test](https://explorable.com/f-test) or [here](https://www.itl.nist.gov/div898/handbook/eda/section3/eda359.htm). This one is a test for tests. The t-test assumes that the data is more or less normally distributed and that the variance is equal
# - Student's t-test
# - Z-Test
# - ANOVA (Analysis of variance, One-way, Two-way, Factorial, Repeated measures)
#
# ## Analysis
# - [Power analysis](https://machinelearningmastery.com/statistical-power-and-power-analysis-in-python/)
#
# ## Regression metrics
# - Mean absolute error
# - Mean square error
# - R2 score
# - Preprocessing
# - Standardization
# - Normalization
# - Binarization
# - Encoding categorical features
# - Imputing missing values
# - Generating polynomial features
#
# ## Reference
# - https://explorable.com/statistics-tutorial
# - [Biological Statistics PDF](http://www.biostathandbook.com/index.html)
# - https://stattrek.com/ This site has various topics to explore.
# - https://www.itl.nist.gov/div898/handbook/index.htm
# - https://explorable.com/statistics-tutorial
